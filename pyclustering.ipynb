# %%
from pyclustering.cluster.kmedoids import kmedoids
from pyclustering.cluster.clarans import clarans
from pyclustering.cluster import cluster_visualizer
from pyclustering.utils import read_sample
from pyclustering.samples.definitions import FCPS_SAMPLES

import pickle
import distance

# %%
# Load list of points for cluster analysis.
sample = read_sample(FCPS_SAMPLES.SAMPLE_TWO_DIAMONDS)
# Set random initial medoids.
initial_medoids = [1, 500, 750]
# Create instance of K-Medoids algorithm.
kmedoids_instance = kmedoids(sample, initial_medoids)
# Run cluster analysis and obtain results.
kmedoids_instance.process()
clusters = kmedoids_instance.get_clusters()
# Show allocated clusters.
print(clusters)
# Display clusters.
visualizer = cluster_visualizer()
visualizer.append_clusters(clusters, sample)
visualizer.show()

# %%
lev_matrix = pickle.load( open( "./lev_similarity.data", "rb" ) )
words = pickle.load( open( "./words.data", "rb" ) )
affprop = pickle.load( open( "./affinity_propagation_cluster.data", "rb" ) )

# %%
initial_medoids = list(range(2,1000))

kmedoids_instance = clarans(lev_matrix, initial_medoids, data_type='distance_matrix')
kmedoids_instance.process()
clusters = kmedoids_instance.get_clusters()

# %%
for cluster in clusters:
    cluster_words = []
    for word_index in cluster:
        cluster_words.append(words[word_index])
    print(' '.join(cluster_words))
    print(' ')
# Out:
# and destruction superficial tuberculosis osteomyelitis distribution protective progressive difficulties territories respectfully nevertheless epithelioma leucocytosis destructive extremities successfully recollection irresistible exclusively dissolution supervision imperfectly proposition proprietors streptococci symmetrical impossibility irrepressible physiological perceptible superiority thoughtfully noiselessly irresistibly hyperostosis respectively superfluous _tuberculous electrolysis restrictive furthermore streptococcus compressible tuberculin projectiles
#
# ...
